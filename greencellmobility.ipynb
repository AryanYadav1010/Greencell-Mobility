# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanYadav1010/Greencell-Mobility/blob/main/greencellmobility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Greencell Mobility

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing the datafile
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-6be5fdcf-4518-478f-87c7-8489a83a3c86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6be5fdcf-4518-478f-87c7-8489a83a3c86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Create a DataFrame
data = pd.DataFrame({'Date': dates, 'Price': prices})

# Save data to an Excel file
data.to_csv('greencellmobility.csv', index=False)

# %%
# Read data from Excel into a Pandas DataFrame
data = pd.read_csv('greencellmobility.csv')
print(df.head())
# Out:
#          Date  Values
# 0  2023-01-01       3
# 1  2023-01-02       7
# 2  2023-01-03       5
# 3  2023-01-04       9

# %%
# Plotting using Matplotlib
plt.figure(figsize=(40, 10))
plt.plot(data['Date'], data['Price'], label='Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Price v/s Date')
plt.legend()
plt.show()

# %%
# Plotting using Matplotlib
# Adding moving averages
data['10-Day MA'] = data['Price'].rolling(window=10).mean()
data['50-Day MA'] = data['Price'].rolling(window=50).mean()

# Plotting with moving averages
plt.figure(figsize=(40, 10))
plt.plot(data['Date'], data['Price'], label='Price')
plt.plot(data['Date'], data['10-Day MA'], label='10-Day MA')
plt.plot(data['Date'], data['50-Day MA'], label='50-Day MA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Price v/s Date')
plt.legend()
plt.show()
